# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# 讀取圖檔
img = cv2.imread('picture_data/1.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img
# Out:
# array([[[ 7, 33,  0],
#         [ 5, 31,  0],
#         [ 4, 30,  0],
#         ...,
#         [ 1,  8,  0],
#         [ 0,  8,  0],
#         [ 0,  8,  0]],
#
#        [[ 6, 32,  0],
#         [ 5, 31,  0],
#         [ 6, 32,  0],
#         ...,
#         [ 1,  8,  0],
#         [ 0,  7,  0],
#         [ 0,  8,  0]],
#
#        [[ 7, 30,  0],
#         [ 6, 29,  0],
#         [ 6, 32,  0],
#         ...,
#         [ 1,  8,  0],
#         [ 0,  7,  0],
#         [ 0,  9,  0]],
#
#        ...,
#
#        [[ 0, 12,  0],
#         [ 0, 15,  0],
#         [ 0, 16,  1],
#         ...,
#         [ 8, 16,  4],
#         [ 8, 16,  4],
#         [ 8, 16,  4]],
#
#        [[ 0, 11,  0],
#         [ 0, 13,  0],
#         [ 0, 13,  0],
#         ...,
#         [ 6, 16,  4],
#         [ 8, 15,  6],
#         [ 9, 16,  7]],
#
#        [[ 0, 11,  0],
#         [ 0, 12,  0],
#         [ 0, 12,  0],
#         ...,
#         [ 5, 15,  3],
#         [ 8, 15,  6],
#         [ 7, 14,  5]]], dtype=uint8)

# %%
# https://gist.github.com/mstfldmr/45d6e47bb661800b982c39d30215bc88
# we will find the color is strange. it is because the order of color from cv2.imread is bgr !!!
# we will need to change the color channel to rgb
plt.imshow(img)

# %%
# change the color channel to rgb
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
